# %%
import numpy as np

# %%
s=np.array([
    [5,3,4,6,7,8,9,1,2],
    [6,7,2,1,9,5,3,4,8],
    [1,9,8,3,4,2,5,6,7],

    [8,5,9,7,6,1,4,2,3],
    [4,2,6,8,5,3,7,9,1],
    [7,1,3,9,2,4,8,5,6],

    [9,6,1,5,3,7,2,8,4],
    [2,8,7,4,1,9,6,3,5],
    [3,4,5,2,8,6,1,7,9]
])
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %%
# summation of each row 
sr=np.sum(s,axis=1)
sr
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
sr[ : : ]==45
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
# summation of each column
sc=np.sum(s,axis=0)
sc
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
#total sum
a=s.sum()
a
# Out:
# np.int64(405)

# %%
#is each column sum is equal 45
b=sc[: : ]==45
for i in b:
    if i==0:
        print("suduko is not valid")
        break 
        
else:
        print("sudoko is correct")
# Out:
# sudoko is correct

# %%
s
# Out:
# array([[5, 3, 4, 6, 7, 8, 9, 1, 2],
#        [6, 7, 2, 1, 9, 5, 3, 4, 8],
#        [1, 9, 8, 3, 4, 2, 5, 6, 7],
#        [8, 5, 9, 7, 6, 1, 4, 2, 3],
#        [4, 2, 6, 8, 5, 3, 7, 9, 1],
#        [7, 1, 3, 9, 2, 4, 8, 5, 6],
#        [9, 6, 1, 5, 3, 7, 2, 8, 4],
#        [2, 8, 7, 4, 1, 9, 6, 3, 5],
#        [3, 4, 5, 2, 8, 6, 1, 7, 9]])

# %%
#slicing first square
s1=s[ :3, :3]
s1
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
s1.sum()
# Out:
# np.int64(45)

# %%
s2=s[:3,3:6]
s2
# Out:
# array([[6, 7, 8],
#        [1, 9, 5],
#        [3, 4, 2]])

# %%
s9=s[6:,6:]
s9
# Out:
# array([[2, 8, 4],
#        [6, 3, 5],
#        [1, 7, 9]])

# %%
len(s)
# Out:
# 9

# %%
#each square print using loop
for i in range( 0,len(s),3):
    for j in range(0,len(s),3):
        print(s[i:i+3,j:j+3])
# Out:
# [[5 3 4]
#  [6 7 2]
#  [1 9 8]]
# [[6 7 8]
#  [1 9 5]
#  [3 4 2]]
# [[9 1 2]
#  [3 4 8]
#  [5 6 7]]
# [[8 5 9]
#  [4 2 6]
#  [7 1 3]]
# [[7 6 1]
#  [8 5 3]
#  [9 2 4]]
# [[4 2 3]
#  [7 9 1]
#  [8 5 6]]
# [[9 6 1]
#  [2 8 7]
#  [3 4 5]]
# [[5 3 7]
#  [4 1 9]
#  [2 8 6]]
# [[2 8 4]
#  [6 3 5]
#  [1 7 9]]

# %%
#each square sum = 45
for i in range( 0,len(s),3):
    for j in range(0,len(s),3):
        n=s[i:i+3,j:j+3]
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
